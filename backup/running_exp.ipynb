# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from tqdm.auto import tqdm
from joblib import Parallel, delayed
from methods import *
from experiments import *

random_seed = 42
threshs = [.5,1.5,3]
benchs = ['MMLU', 'ARC-C', 'HellaSwag', 'Winograd', 'TruthfulQA','GSM8K', 'XWinograd', 'HumanEval']

# %%
results = {}

for filter_families in [None, True, False]:
    for bench in tqdm(benchs):
        ### Preparing data
        data = pd.read_csv('data/base_llm_benchmark_eval.csv')
        data = data.loc[-np.isnan(data['FLOPs (1E21)'])]
        
        fam_encoder = LabelEncoder()
        fam_encoder.fit(data['Model Family'])
        data['T'] = data['Pretraining Data Size (T)']
        data['S'] = data['Model Size (B)']
        data['F'] = data['FLOPs (1E21)']
        data['family'] = data['Model Family']

        bad_families = ['XGLM','OPT','Codegen','GPT-Neo/J','Pythia','BLOOM']
        #bad_families = ['XGLM','OPT','StarCoder','StableLM','Pythia','GPT-Neo/J','BLOOM']
        if filter_families is None:
            pass
        elif filter_families:
            data = data.loc[[f not in bad_families for f in data.family]]
        else:
            data = data.loc[[f in bad_families for f in data.family]]
            
        data['Y'] = data[bench]
        data = data[['family','Y','T','S','F',]]
        data = data.loc[-np.isnan(data['Y'])]
        data = data.sort_values(by=['family','S']).reset_index(drop=True)
        
        data['logT'] = np.log(data['T'])
        data['logS'] = np.log(data['S'])
        data['logF'] = np.log(data['F'])
        data['logS*logT'] = data['logS']*data['logT']
        
        data['T_verylow'] = 0
        data['T_low'] = 0
        data['T_mid'] = 0
        data['T_high'] = 0
        data.loc[(np.array(data['T'])<threshs[0]), 'T_verylow'] = 1
        data.loc[(np.array(data['T'])>=threshs[0])*(np.array(data['T'])<threshs[1]), 'T_low'] = 1
        data.loc[(np.array(data['T'])>=threshs[1])*(np.array(data['T'])<threshs[2]), 'T_mid'] = 1
        data.loc[(np.array(data['T'])>=threshs[2]), 'T_high'] = 1
        
        ### Preparing data
        avail_families = []
        for fam in np.unique(data['family']):
            if np.sum(data['family']==fam)>=2:
                avail_families.append(fam)
        
        results[bench] = Parallel(n_jobs=-1, verbose=10)(
                                     delayed(get_results)(data, test_family) for test_family in avail_families
                                  )
        
        ### Saving results
        np.save(f"results/results_filter-{filter_families}.npy", results)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  25 | elapsed:  3.6min remaining: 19.1min
# [Parallel(n_jobs=-1)]: Done   7 out of  25 | elapsed:  3.7min remaining:  9.4min
# [Parallel(n_jobs=-1)]: Done  10 out of  25 | elapsed:  3.7min remaining:  5.6min
# [Parallel(n_jobs=-1)]: Done  13 out of  25 | elapsed:  3.8min remaining:  3.5min
# [Parallel(n_jobs=-1)]: Done  16 out of  25 | elapsed:  3.8min remaining:  2.1min
# [Parallel(n_jobs=-1)]: Done  19 out of  25 | elapsed:  3.8min remaining:  1.2min
# [Parallel(n_jobs=-1)]: Done  22 out of  25 | elapsed:  3.8min remaining:   31.4s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:  3.9min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done   3 out of  24 | elapsed:   32.4s remaining:  3.8min
# [Parallel(n_jobs=-1)]: Done   6 out of  24 | elapsed:   33.3s remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done   9 out of  24 | elapsed:   34.5s remaining:   57.4s
# [Parallel(n_jobs=-1)]: Done  12 out of  24 | elapsed:   35.5s remaining:   35.5s
# [Parallel(n_jobs=-1)]: Done  15 out of  24 | elapsed:   38.6s remaining:   23.1s
# [Parallel(n_jobs=-1)]: Done  18 out of  24 | elapsed:  1.1min remaining:   21.2s
# [Parallel(n_jobs=-1)]: Done  21 out of  24 | elapsed:  1.1min remaining:    9.4s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:  1.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  25 | elapsed:   31.8s remaining:  2.8min
# [Parallel(n_jobs=-1)]: Done   7 out of  25 | elapsed:   33.3s remaining:  1.4min
# [Parallel(n_jobs=-1)]: Done  10 out of  25 | elapsed:   34.1s remaining:   51.2s
# [Parallel(n_jobs=-1)]: Done  13 out of  25 | elapsed:   35.6s remaining:   32.9s
# [Parallel(n_jobs=-1)]: Done  16 out of  25 | elapsed:   36.4s remaining:   20.5s
# [Parallel(n_jobs=-1)]: Done  19 out of  25 | elapsed:   37.0s remaining:   11.7s
# [Parallel(n_jobs=-1)]: Done  22 out of  25 | elapsed:   37.9s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   40.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  25 | elapsed:   58.2s remaining:  5.1min
# [Parallel(n_jobs=-1)]: Done   7 out of  25 | elapsed:  1.0min remaining:  2.6min
# [Parallel(n_jobs=-1)]: Done  10 out of  25 | elapsed:  1.0min remaining:  1.6min
# [Parallel(n_jobs=-1)]: Done  13 out of  25 | elapsed:  1.1min remaining:   58.6s
# [Parallel(n_jobs=-1)]: Done  16 out of  25 | elapsed:  1.1min remaining:   36.5s
# [Parallel(n_jobs=-1)]: Done  19 out of  25 | elapsed:  1.1min remaining:   20.7s
# [Parallel(n_jobs=-1)]: Done  22 out of  25 | elapsed:  1.1min remaining:    9.1s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:  1.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  25 | elapsed:  1.4min remaining:  7.2min
# [Parallel(n_jobs=-1)]: Done   7 out of  25 | elapsed:  1.4min remaining:  3.7min
# [Parallel(n_jobs=-1)]: Done  10 out of  25 | elapsed:  1.5min remaining:  2.2min
# [Parallel(n_jobs=-1)]: Done  13 out of  25 | elapsed:  1.5min remaining:  1.4min
# [Parallel(n_jobs=-1)]: Done  16 out of  25 | elapsed:  1.6min remaining:   52.4s
# [Parallel(n_jobs=-1)]: Done  19 out of  25 | elapsed:  1.6min remaining:   29.9s
# [Parallel(n_jobs=-1)]: Done  22 out of  25 | elapsed:  1.6min remaining:   13.3s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:  1.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  25 | elapsed:   37.4s remaining:  3.3min
# [Parallel(n_jobs=-1)]: Done   7 out of  25 | elapsed:   38.4s remaining:  1.6min
# [Parallel(n_jobs=-1)]: Done  10 out of  25 | elapsed:   39.1s remaining:   58.7s
# [Parallel(n_jobs=-1)]: Done  13 out of  25 | elapsed:   40.2s remaining:   37.1s
# [Parallel(n_jobs=-1)]: Done  16 out of  25 | elapsed:   42.6s remaining:   24.0s
# [Parallel(n_jobs=-1)]: Done  19 out of  25 | elapsed:   43.2s remaining:   13.7s
# [Parallel(n_jobs=-1)]: Done  22 out of  25 | elapsed:   43.6s remaining:    5.9s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   44.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  19 | elapsed:   49.5s remaining:  7.0min
# [Parallel(n_jobs=-1)]: Done   4 out of  19 | elapsed:   53.0s remaining:  3.3min
# [Parallel(n_jobs=-1)]: Done   6 out of  19 | elapsed:   55.4s remaining:  2.0min
# [Parallel(n_jobs=-1)]: Done   8 out of  19 | elapsed:   58.1s remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done  10 out of  19 | elapsed:   58.7s remaining:   52.8s
# [Parallel(n_jobs=-1)]: Done  12 out of  19 | elapsed:   59.5s remaining:   34.7s
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:  1.0min remaining:   21.5s
# [Parallel(n_jobs=-1)]: Done  16 out of  19 | elapsed:  1.0min remaining:   11.4s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:  1.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  18 | elapsed:   38.4s remaining:  3.2min
# [Parallel(n_jobs=-1)]: Done   5 out of  18 | elapsed:   38.6s remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done   7 out of  18 | elapsed:   39.0s remaining:  1.0min
# [Parallel(n_jobs=-1)]: Done   9 out of  18 | elapsed:   39.4s remaining:   39.4s
# [Parallel(n_jobs=-1)]: Done  11 out of  18 | elapsed:   39.8s remaining:   25.3s
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:   40.6s remaining:   15.6s
# [Parallel(n_jobs=-1)]: Done  15 out of  18 | elapsed:   41.0s remaining:    8.2s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:   45.3s finished
#   0%|          | 0/8 [00:00<?, ?it/s]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  19 | elapsed:  1.0min remaining:  8.8min
# [Parallel(n_jobs=-1)]: Done   4 out of  19 | elapsed:  1.1min remaining:  3.9min
# [Parallel(n_jobs=-1)]: Done   6 out of  19 | elapsed:  1.2min remaining:  2.5min
# [Parallel(n_jobs=-1)]: Done   8 out of  19 | elapsed:  1.2min remaining:  1.6min
# [Parallel(n_jobs=-1)]: Done  10 out of  19 | elapsed:  1.2min remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done  12 out of  19 | elapsed:  1.2min remaining:   42.3s
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:  1.2min remaining:   26.0s
# [Parallel(n_jobs=-1)]: Done  16 out of  19 | elapsed:  1.2min remaining:   13.9s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:  1.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  18 | elapsed:   24.8s remaining:  2.1min
# [Parallel(n_jobs=-1)]: Done   5 out of  18 | elapsed:   25.1s remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done   7 out of  18 | elapsed:   25.1s remaining:   39.5s
# [Parallel(n_jobs=-1)]: Done   9 out of  18 | elapsed:   25.8s remaining:   25.8s
# [Parallel(n_jobs=-1)]: Done  11 out of  18 | elapsed:   25.8s remaining:   16.4s
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:   26.2s remaining:   10.1s
# [Parallel(n_jobs=-1)]: Done  15 out of  18 | elapsed:   28.1s remaining:    5.6s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:   29.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  19 | elapsed:   27.9s remaining:  3.9min
# [Parallel(n_jobs=-1)]: Done   4 out of  19 | elapsed:   28.1s remaining:  1.8min
# [Parallel(n_jobs=-1)]: Done   6 out of  19 | elapsed:   28.6s remaining:  1.0min
# [Parallel(n_jobs=-1)]: Done   8 out of  19 | elapsed:   29.5s remaining:   40.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  19 | elapsed:   31.0s remaining:   27.9s
# [Parallel(n_jobs=-1)]: Done  12 out of  19 | elapsed:   31.9s remaining:   18.6s
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:   33.2s remaining:   11.9s
# [Parallel(n_jobs=-1)]: Done  16 out of  19 | elapsed:   34.4s remaining:    6.5s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   41.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  19 | elapsed:   40.0s remaining:  5.7min
# [Parallel(n_jobs=-1)]: Done   4 out of  19 | elapsed:   41.1s remaining:  2.6min
# [Parallel(n_jobs=-1)]: Done   6 out of  19 | elapsed:   41.1s remaining:  1.5min
# [Parallel(n_jobs=-1)]: Done   8 out of  19 | elapsed:   41.3s remaining:   56.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  19 | elapsed:   42.3s remaining:   38.1s
# [Parallel(n_jobs=-1)]: Done  12 out of  19 | elapsed:   42.4s remaining:   24.7s
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:   43.2s remaining:   15.4s
# [Parallel(n_jobs=-1)]: Done  16 out of  19 | elapsed:   44.2s remaining:    8.3s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   45.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  19 | elapsed:   56.9s remaining:  8.1min
# [Parallel(n_jobs=-1)]: Done   4 out of  19 | elapsed:  1.0min remaining:  3.8min
# [Parallel(n_jobs=-1)]: Done   6 out of  19 | elapsed:  1.1min remaining:  2.4min
# [Parallel(n_jobs=-1)]: Done   8 out of  19 | elapsed:  1.1min remaining:  1.6min
# [Parallel(n_jobs=-1)]: Done  10 out of  19 | elapsed:  1.2min remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done  12 out of  19 | elapsed:  1.2min remaining:   43.0s
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:  1.2min remaining:   26.7s
# [Parallel(n_jobs=-1)]: Done  16 out of  19 | elapsed:  1.3min remaining:   14.3s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:  1.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  19 | elapsed:   38.0s remaining:  5.4min
# [Parallel(n_jobs=-1)]: Done   4 out of  19 | elapsed:   39.1s remaining:  2.4min
# [Parallel(n_jobs=-1)]: Done   6 out of  19 | elapsed:   40.8s remaining:  1.5min
# [Parallel(n_jobs=-1)]: Done   8 out of  19 | elapsed:   41.5s remaining:   57.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  19 | elapsed:   41.9s remaining:   37.7s
# [Parallel(n_jobs=-1)]: Done  12 out of  19 | elapsed:   44.9s remaining:   26.2s
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:   45.8s remaining:   16.3s
# [Parallel(n_jobs=-1)]: Done  16 out of  19 | elapsed:   46.9s remaining:    8.8s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   51.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  14 | elapsed:   49.2s remaining:  3.0min
# [Parallel(n_jobs=-1)]: Done   5 out of  14 | elapsed:   50.3s remaining:  1.5min
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:   53.2s remaining:   53.2s
# [Parallel(n_jobs=-1)]: Done   9 out of  14 | elapsed:   57.0s remaining:   31.7s
# [Parallel(n_jobs=-1)]: Done  11 out of  14 | elapsed:   57.8s remaining:   15.8s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:  1.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  13 | elapsed:   28.5s remaining:  2.6min
# [Parallel(n_jobs=-1)]: Done   4 out of  13 | elapsed:   29.3s remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done   6 out of  13 | elapsed:   29.6s remaining:   34.6s
# [Parallel(n_jobs=-1)]: Done   8 out of  13 | elapsed:   30.6s remaining:   19.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  13 | elapsed:   32.0s remaining:    9.6s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:   40.2s finished
#   0%|          | 0/8 [00:00<?, ?it/s]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   6 | elapsed:   12.1s remaining:   24.3s
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:   13.2s remaining:   13.2s
# [Parallel(n_jobs=-1)]: Done   4 out of   6 | elapsed:   13.5s remaining:    6.8s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:   14.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   6 | elapsed:   14.8s remaining:   29.5s
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:   15.1s remaining:   15.1s
# [Parallel(n_jobs=-1)]: Done   4 out of   6 | elapsed:   15.4s remaining:    7.7s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:   17.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   6 | elapsed:   15.7s remaining:   31.3s
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:   16.4s remaining:   16.4s
# [Parallel(n_jobs=-1)]: Done   4 out of   6 | elapsed:   16.5s remaining:    8.3s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:   19.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   6 | elapsed:    9.6s remaining:   19.2s
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:   10.9s remaining:   10.9s
# [Parallel(n_jobs=-1)]: Done   4 out of   6 | elapsed:   12.4s remaining:    6.2s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:   15.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   6 | elapsed:   15.4s remaining:   30.7s
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:   19.2s remaining:   19.2s
# [Parallel(n_jobs=-1)]: Done   4 out of   6 | elapsed:   21.0s remaining:   10.5s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:   23.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   6 | elapsed:    7.8s remaining:   15.5s
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    7.9s remaining:    7.9s
# [Parallel(n_jobs=-1)]: Done   4 out of   6 | elapsed:    8.0s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    8.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   18.1s remaining:   27.1s
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:   19.5s remaining:   13.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   23.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    9.1s remaining:   13.7s
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:    9.6s remaining:    6.4s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   11.0s finished
